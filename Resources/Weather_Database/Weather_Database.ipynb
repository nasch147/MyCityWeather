# %%
#import dependencies
import pandas as pd
import random
import numpy as np
from citipy import citipy
import requests
from config import Weather_api_key
import time
from datetime import datetime

# %%
#create random longs and lats
lats = np.random.uniform(-90.000,90.000, size=2000)
longs = np.random.uniform(-180.000,180.000, size=2000)
lats_longs = zip(lats,longs)
#add to lsit
coordinates = list(lats_longs)

# %%
# Create a list for cities.
cities = []
# Identify the nearest city for latitude and longitude pair.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#build url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + Weather_api_key

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:  
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description" : city_desc,
                          "Date": city_date})
    
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass                     



# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | magadan
# Processing Record 3 of Set 1 | kavieng
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | seoul
# Processing Record 7 of Set 1 | krasnoselkup
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | karauzyak
# City not found. Skipping...
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | hithadhoo
# Processing Record 13 of Set 1 | akureyri
# Processing Record 14 of Set 1 | altay
# Processing Record 15 of Set 1 | barrow
# Processing Record 16 of Set 1 | kodiak
# Processing Record 17 of Set 1 | flinders
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | lyubar
# Processing Record 20 of Set 1 | airai
# Processing Record 21 of Set 1 | avera
# Processing Record 22 of Set 1 | sitka
# Processing Record 23 of Set 1 | ostersund
# Processing Record 24 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 25 of Set 1 | esperance
# Processing Record 26 of Set 1 | pathein
# Processing Record 27 of Set 1 | kahului
# Processing Record 28 of Set 1 | lieksa
# Processing Record 29 of Set 1 | thompson
# Processing Record 30 of Set 1 | saskylakh
# Processing Record 31 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 1 | kanker
# Processing Record 33 of Set 1 | tubruq
# City not found. Skipping...
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | mglin
# Processing Record 36 of Set 1 | siretel
# Processing Record 37 of Set 1 | kaliua
# Processing Record 38 of Set 1 | krasnokamensk
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | yenagoa
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | ulaanbaatar
# Processing Record 45 of Set 1 | nan
# Processing Record 46 of Set 1 | tiksi
# Processing Record 47 of Set 1 | greymouth
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | mount isa
# Processing Record 2 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 2 | cape town
# Processing Record 4 of Set 2 | talnakh
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | luderitz
# Processing Record 7 of Set 2 | takoradi
# Processing Record 8 of Set 2 | lorengau
# Processing Record 9 of Set 2 | cherskiy
# Processing Record 10 of Set 2 | litoral del san juan
# City not found. Skipping...
# Processing Record 11 of Set 2 | norman wells
# Processing Record 12 of Set 2 | naryan-mar
# Processing Record 13 of Set 2 | saint-philippe
# Processing Record 14 of Set 2 | san patricio
# Processing Record 15 of Set 2 | nalut
# Processing Record 16 of Set 2 | portland
# Processing Record 17 of Set 2 | barwala
# Processing Record 18 of Set 2 | longyearbyen
# Processing Record 19 of Set 2 | chincha alta
# Processing Record 20 of Set 2 | east london
# Processing Record 21 of Set 2 | yarada
# Processing Record 22 of Set 2 | bambous virieux
# Processing Record 23 of Set 2 | punta arenas
# Processing Record 24 of Set 2 | provideniya
# Processing Record 25 of Set 2 | katsuura
# Processing Record 26 of Set 2 | shellbrook
# Processing Record 27 of Set 2 | thaton
# Processing Record 28 of Set 2 | taoudenni
# Processing Record 29 of Set 2 | puerto escondido
# Processing Record 30 of Set 2 | carlos barbosa
# Processing Record 31 of Set 2 | sioux lookout
# Processing Record 32 of Set 2 | yellowknife
# Processing Record 33 of Set 2 | tautira
# Processing Record 34 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 35 of Set 2 | korla
# Processing Record 36 of Set 2 | yerazgavors
# Processing Record 37 of Set 2 | avarua
# Processing Record 38 of Set 2 | vanatori
# Processing Record 39 of Set 2 | kangaatsiaq
# Processing Record 40 of Set 2 | ilulissat
# Processing Record 41 of Set 2 | bluff
# Processing Record 42 of Set 2 | bristol
# Processing Record 43 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 2 | kavaratti
# Processing Record 45 of Set 2 | grindavik
# Processing Record 46 of Set 2 | bengkulu
# Processing Record 47 of Set 2 | isangel
# Processing Record 48 of Set 2 | plettenberg bay
# Processing Record 49 of Set 2 | healdsburg
# Processing Record 50 of Set 2 | kuva
# City not found. Skipping...
# Processing Record 1 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 3 | butaritari
# Processing Record 3 of Set 3 | mahebourg
# Processing Record 4 of Set 3 | udachnyy
# Processing Record 5 of Set 3 | antofagasta
# Processing Record 6 of Set 3 | hermanus
# Processing Record 7 of Set 3 | barcelos
# Processing Record 8 of Set 3 | jalu
# Processing Record 9 of Set 3 | bethel
# Processing Record 10 of Set 3 | haines junction
# Processing Record 11 of Set 3 | andselv
# City not found. Skipping...
# Processing Record 12 of Set 3 | mar del plata
# Processing Record 13 of Set 3 | cloquet
# Processing Record 14 of Set 3 | port alfred
# Processing Record 15 of Set 3 | coahuayana
# Processing Record 16 of Set 3 | atuona
# Processing Record 17 of Set 3 | chokurdakh
# Processing Record 18 of Set 3 | butembo
# Processing Record 19 of Set 3 | atasu
# Processing Record 20 of Set 3 | hasaki
# Processing Record 21 of Set 3 | coquimbo
# Processing Record 22 of Set 3 | sheridan
# Processing Record 23 of Set 3 | castro
# Processing Record 24 of Set 3 | saldanha
# Processing Record 25 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 3 | lebu
# Processing Record 27 of Set 3 | matara
# Processing Record 28 of Set 3 | lynn haven
# Processing Record 29 of Set 3 | alofi
# Processing Record 30 of Set 3 | rawson
# Processing Record 31 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 3 | ponta do sol
# Processing Record 33 of Set 3 | boddam
# Processing Record 34 of Set 3 | namibe
# Processing Record 35 of Set 3 | ustye
# Processing Record 36 of Set 3 | petatlan
# Processing Record 37 of Set 3 | hay river
# Processing Record 38 of Set 3 | marsa matruh
# Processing Record 39 of Set 3 | ribeira grande
# Processing Record 40 of Set 3 | cockburn town
# Processing Record 41 of Set 3 | polson
# Processing Record 42 of Set 3 | kesennuma
# City not found. Skipping...
# Processing Record 43 of Set 3 | rocha
# Processing Record 44 of Set 3 | olafsvik
# Processing Record 45 of Set 3 | clyde river
# Processing Record 46 of Set 3 | valle de allende
# Processing Record 47 of Set 3 | lagoa
# Processing Record 48 of Set 3 | rio verde de mato grosso
# Processing Record 49 of Set 3 | nikolskoye
# Processing Record 50 of Set 3 | port macquarie
# Processing Record 1 of Set 4 | tsabong
# Processing Record 2 of Set 4 | saint george
# Processing Record 3 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 4 | te anau
# Processing Record 5 of Set 4 | kitgum
# Processing Record 6 of Set 4 | lhokseumawe
# Processing Record 7 of Set 4 | manokwari
# Processing Record 8 of Set 4 | shimoda
# Processing Record 9 of Set 4 | puerto del rosario
# Processing Record 10 of Set 4 | dikson
# Processing Record 11 of Set 4 | kanniyakumari
# Processing Record 12 of Set 4 | san cristobal
# Processing Record 13 of Set 4 | victoria
# Processing Record 14 of Set 4 | aklavik
# Processing Record 15 of Set 4 | ayr
# Processing Record 16 of Set 4 | nelson bay
# Processing Record 17 of Set 4 | okahandja
# Processing Record 18 of Set 4 | assiniboia
# Processing Record 19 of Set 4 | cairns
# Processing Record 20 of Set 4 | sakakah
# Processing Record 21 of Set 4 | chuy
# Processing Record 22 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 4 | andra
# Processing Record 24 of Set 4 | muisne
# Processing Record 25 of Set 4 | iwanai
# Processing Record 26 of Set 4 | maumere
# Processing Record 27 of Set 4 | nylstroom
# City not found. Skipping...
# Processing Record 28 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 4 | camacha
# Processing Record 30 of Set 4 | springdale
# Processing Record 31 of Set 4 | gamba
# Processing Record 32 of Set 4 | vila franca do campo
# Processing Record 33 of Set 4 | khatanga
# Processing Record 34 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 4 | sarahan
# Processing Record 36 of Set 4 | kysyl-syr
# Processing Record 37 of Set 4 | daxian
# City not found. Skipping...
# Processing Record 38 of Set 4 | saint-pierre
# Processing Record 39 of Set 4 | capreol
# Processing Record 40 of Set 4 | narsaq
# Processing Record 41 of Set 4 | walvis bay
# Processing Record 42 of Set 4 | mpanda
# Processing Record 43 of Set 4 | kaitangata
# Processing Record 44 of Set 4 | torbay
# Processing Record 45 of Set 4 | asau
# Processing Record 46 of Set 4 | arraial do cabo
# Processing Record 47 of Set 4 | awjilah
# Processing Record 48 of Set 4 | bredasdorp
# Processing Record 49 of Set 4 | severo-kurilsk
# Processing Record 50 of Set 4 | fortuna
# Processing Record 1 of Set 5 | codrington
# Processing Record 2 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 5 | honningsvag
# Processing Record 4 of Set 5 | necochea
# Processing Record 5 of Set 5 | baillif
# Processing Record 6 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 5 | comodoro rivadavia
# Processing Record 8 of Set 5 | darab
# Processing Record 9 of Set 5 | mikuni
# Processing Record 10 of Set 5 | baykit
# Processing Record 11 of Set 5 | abu dhabi
# Processing Record 12 of Set 5 | novovarshavka
# Processing Record 13 of Set 5 | mtambile
# Processing Record 14 of Set 5 | pitimbu
# Processing Record 15 of Set 5 | bababe
# City not found. Skipping...
# Processing Record 16 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 17 of Set 5 | port hardy
# Processing Record 18 of Set 5 | pucara
# Processing Record 19 of Set 5 | vaitape
# Processing Record 20 of Set 5 | porto walter
# Processing Record 21 of Set 5 | namatanai
# Processing Record 22 of Set 5 | harper
# Processing Record 23 of Set 5 | makakilo city
# Processing Record 24 of Set 5 | poum
# Processing Record 25 of Set 5 | paamiut
# Processing Record 26 of Set 5 | cabo san lucas
# Processing Record 27 of Set 5 | russell
# Processing Record 28 of Set 5 | klaksvik
# Processing Record 29 of Set 5 | richards bay
# Processing Record 30 of Set 5 | lady frere
# Processing Record 31 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 5 | margate
# Processing Record 33 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 5 | andenes
# Processing Record 35 of Set 5 | gurupi
# Processing Record 36 of Set 5 | khilok
# Processing Record 37 of Set 5 | mamallapuram
# Processing Record 38 of Set 5 | souillac
# Processing Record 39 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 5 | pevek
# Processing Record 41 of Set 5 | pisco
# Processing Record 42 of Set 5 | upernavik
# Processing Record 43 of Set 5 | sume
# Processing Record 44 of Set 5 | acarau
# Processing Record 45 of Set 5 | iqaluit
# Processing Record 46 of Set 5 | gavle
# Processing Record 47 of Set 5 | portadown
# Processing Record 48 of Set 5 | bezhetsk
# Processing Record 49 of Set 5 | matola
# Processing Record 50 of Set 5 | guerrero negro
# Processing Record 1 of Set 6 | darhan
# Processing Record 2 of Set 6 | rio bueno
# Processing Record 3 of Set 6 | la paz
# Processing Record 4 of Set 6 | ushtobe
# Processing Record 5 of Set 6 | ust-charyshskaya pristan
# Processing Record 6 of Set 6 | sao filipe
# Processing Record 7 of Set 6 | lillooet
# Processing Record 8 of Set 6 | roald
# Processing Record 9 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 6 | morro bay
# Processing Record 11 of Set 6 | arkhipo-osipovka
# Processing Record 12 of Set 6 | hilo
# Processing Record 13 of Set 6 | tasiilaq
# Processing Record 14 of Set 6 | xiantao
# Processing Record 15 of Set 6 | lata
# Processing Record 16 of Set 6 | port-gentil
# Processing Record 17 of Set 6 | miles city
# Processing Record 18 of Set 6 | kunszentmarton
# Processing Record 19 of Set 6 | kamenka
# Processing Record 20 of Set 6 | kaeo
# Processing Record 21 of Set 6 | kingaroy
# Processing Record 22 of Set 6 | teahupoo
# Processing Record 23 of Set 6 | ahipara
# Processing Record 24 of Set 6 | boende
# Processing Record 25 of Set 6 | malanje
# Processing Record 26 of Set 6 | sulangan
# Processing Record 27 of Set 6 | beisfjord
# Processing Record 28 of Set 6 | svetlogorsk
# Processing Record 29 of Set 6 | bubaque
# Processing Record 30 of Set 6 | phumi samraong
# City not found. Skipping...
# Processing Record 31 of Set 6 | romanovo
# Processing Record 32 of Set 6 | kupang
# Processing Record 33 of Set 6 | gikongoro
# Processing Record 34 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 6 | nanakuli
# Processing Record 36 of Set 6 | yarkovo
# Processing Record 37 of Set 6 | georgetown
# Processing Record 38 of Set 6 | mecca
# Processing Record 39 of Set 6 | laguna
# Processing Record 40 of Set 6 | vila velha
# Processing Record 41 of Set 6 | calama
# Processing Record 42 of Set 6 | santa flavia
# Processing Record 43 of Set 6 | oyama
# Processing Record 44 of Set 6 | pljevlja
# Processing Record 45 of Set 6 | sarkand
# Processing Record 46 of Set 6 | tigil
# Processing Record 47 of Set 6 | half moon bay
# Processing Record 48 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 6 | jining
# Processing Record 50 of Set 6 | villa de reyes
# Processing Record 1 of Set 7 | sovetskiy
# Processing Record 2 of Set 7 | okakarara
# Processing Record 3 of Set 7 | portobelo
# Processing Record 4 of Set 7 | faanui
# Processing Record 5 of Set 7 | murgab
# Processing Record 6 of Set 7 | lubango
# Processing Record 7 of Set 7 | meulaboh
# Processing Record 8 of Set 7 | tuatapere
# Processing Record 9 of Set 7 | primorsk
# Processing Record 10 of Set 7 | baghdad
# Processing Record 11 of Set 7 | rawa mazowiecka
# Processing Record 12 of Set 7 | egvekinot
# Processing Record 13 of Set 7 | san vicente
# Processing Record 14 of Set 7 | chicama
# Processing Record 15 of Set 7 | karratha
# Processing Record 16 of Set 7 | goderich
# Processing Record 17 of Set 7 | zhigansk
# Processing Record 18 of Set 7 | sawakin
# Processing Record 19 of Set 7 | maniitsoq
# Processing Record 20 of Set 7 | calabozo
# Processing Record 21 of Set 7 | wamba
# Processing Record 22 of Set 7 | matay
# Processing Record 23 of Set 7 | camopi
# Processing Record 24 of Set 7 | damietta
# Processing Record 25 of Set 7 | axim
# Processing Record 26 of Set 7 | mabaruma
# Processing Record 27 of Set 7 | grand gaube
# Processing Record 28 of Set 7 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 29 of Set 7 | badvel
# Processing Record 30 of Set 7 | erenhot
# Processing Record 31 of Set 7 | lompoc
# Processing Record 32 of Set 7 | port blair
# Processing Record 33 of Set 7 | qaqortoq
# Processing Record 34 of Set 7 | bam
# Processing Record 35 of Set 7 | collie
# Processing Record 36 of Set 7 | jimo
# Processing Record 37 of Set 7 | soyo
# Processing Record 38 of Set 7 | barra patuca
# Processing Record 39 of Set 7 | aksarka
# Processing Record 40 of Set 7 | munster
# Processing Record 41 of Set 7 | ixtapa
# Processing Record 42 of Set 7 | selikhino
# Processing Record 43 of Set 7 | ouadda
# Processing Record 44 of Set 7 | hailar
# Processing Record 45 of Set 7 | touros
# Processing Record 46 of Set 7 | bonavista
# Processing Record 47 of Set 7 | saint-michel-des-saints
# Processing Record 48 of Set 7 | linqiong
# Processing Record 49 of Set 7 | carnarvon
# Processing Record 50 of Set 7 | havre-saint-pierre
# Processing Record 1 of Set 8 | cidreira
# Processing Record 2 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 8 | coro
# Processing Record 4 of Set 8 | mundo nuevo
# Processing Record 5 of Set 8 | el carmen
# Processing Record 6 of Set 8 | norrtalje
# Processing Record 7 of Set 8 | tawnat
# City not found. Skipping...
# Processing Record 8 of Set 8 | nanortalik
# Processing Record 9 of Set 8 | nemuro
# Processing Record 10 of Set 8 | emerald
# Processing Record 11 of Set 8 | katherine
# Processing Record 12 of Set 8 | zhuhai
# Processing Record 13 of Set 8 | biak
# Processing Record 14 of Set 8 | veinticinco de mayo
# Processing Record 15 of Set 8 | college
# Processing Record 16 of Set 8 | oranjemund
# Processing Record 17 of Set 8 | gumdag
# Processing Record 18 of Set 8 | pacific grove
# Processing Record 19 of Set 8 | jingdezhen
# Processing Record 20 of Set 8 | luba
# Processing Record 21 of Set 8 | kushiro
# Processing Record 22 of Set 8 | bereda
# Processing Record 23 of Set 8 | beruwala
# Processing Record 24 of Set 8 | borovoy
# Processing Record 25 of Set 8 | naze
# Processing Record 26 of Set 8 | sinnamary
# Processing Record 27 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 28 of Set 8 | belmonte
# Processing Record 29 of Set 8 | kongolo
# Processing Record 30 of Set 8 | mbuyapey
# Processing Record 31 of Set 8 | evensk
# Processing Record 32 of Set 8 | nhulunbuy
# Processing Record 33 of Set 8 | ca mau
# Processing Record 34 of Set 8 | orillia
# Processing Record 35 of Set 8 | yumen
# Processing Record 36 of Set 8 | camana
# Processing Record 37 of Set 8 | newport
# Processing Record 38 of Set 8 | tilichiki
# Processing Record 39 of Set 8 | atbasar
# Processing Record 40 of Set 8 | cabedelo
# Processing Record 41 of Set 8 | batagay-alyta
# Processing Record 42 of Set 8 | lexington
# Processing Record 43 of Set 8 | pangnirtung
# Processing Record 44 of Set 8 | jurado
# Processing Record 45 of Set 8 | itarema
# Processing Record 46 of Set 8 | wattegama
# Processing Record 47 of Set 8 | muroto
# Processing Record 48 of Set 8 | gijon
# Processing Record 49 of Set 8 | beyneu
# Processing Record 50 of Set 8 | koumac
# Processing Record 1 of Set 9 | tyristrand
# Processing Record 2 of Set 9 | dicabisagan
# Processing Record 3 of Set 9 | carutapera
# Processing Record 4 of Set 9 | tchibanga
# Processing Record 5 of Set 9 | qandala
# Processing Record 6 of Set 9 | burns lake
# Processing Record 7 of Set 9 | ancud
# Processing Record 8 of Set 9 | geraldton
# Processing Record 9 of Set 9 | balykshi
# Processing Record 10 of Set 9 | shubarshi
# Processing Record 11 of Set 9 | los llanos de aridane
# Processing Record 12 of Set 9 | waipawa
# Processing Record 13 of Set 9 | kirillov
# Processing Record 14 of Set 9 | majene
# Processing Record 15 of Set 9 | santa marta
# Processing Record 16 of Set 9 | caravelas
# Processing Record 17 of Set 9 | samarai
# Processing Record 18 of Set 9 | leh
# Processing Record 19 of Set 9 | smidovich
# Processing Record 20 of Set 9 | husavik
# Processing Record 21 of Set 9 | atar
# Processing Record 22 of Set 9 | san bartolome de tirajana
# Processing Record 23 of Set 9 | sur
# Processing Record 24 of Set 9 | ahuimanu
# Processing Record 25 of Set 9 | chapais
# Processing Record 26 of Set 9 | san borja
# Processing Record 27 of Set 9 | havelock
# Processing Record 28 of Set 9 | leeton
# Processing Record 29 of Set 9 | nayoro
# Processing Record 30 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 31 of Set 9 | kaohsiung
# Processing Record 32 of Set 9 | huilong
# Processing Record 33 of Set 9 | srednekolymsk
# Processing Record 34 of Set 9 | barcelona
# Processing Record 35 of Set 9 | tura
# Processing Record 36 of Set 9 | manaure
# Processing Record 37 of Set 9 | eregli
# Processing Record 38 of Set 9 | esmeraldas
# Processing Record 39 of Set 9 | fort nelson
# Processing Record 40 of Set 9 | vardo
# Processing Record 41 of Set 9 | baruun-urt
# Processing Record 42 of Set 9 | grafton
# Processing Record 43 of Set 9 | boa vista
# Processing Record 44 of Set 9 | asosa
# Processing Record 45 of Set 9 | sao jose da coroa grande
# Processing Record 46 of Set 9 | suntar
# Processing Record 47 of Set 9 | teya
# Processing Record 48 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 9 | volgorechensk
# Processing Record 50 of Set 9 | berdigestyakh
# Processing Record 1 of Set 10 | aksu
# Processing Record 2 of Set 10 | xining
# Processing Record 3 of Set 10 | terme
# Processing Record 4 of Set 10 | alamos
# Processing Record 5 of Set 10 | sarangani
# Processing Record 6 of Set 10 | tonj
# Processing Record 7 of Set 10 | hermosillo
# Processing Record 8 of Set 10 | nueva loja
# Processing Record 9 of Set 10 | dudinka
# Processing Record 10 of Set 10 | witu
# Processing Record 11 of Set 10 | ola
# Processing Record 12 of Set 10 | camalu
# Processing Record 13 of Set 10 | dubbo
# Processing Record 14 of Set 10 | bilibino
# Processing Record 15 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 16 of Set 10 | beringovskiy
# Processing Record 17 of Set 10 | nome
# Processing Record 18 of Set 10 | igrim
# Processing Record 19 of Set 10 | yar-sale
# Processing Record 20 of Set 10 | xucheng
# Processing Record 21 of Set 10 | fairbanks
# Processing Record 22 of Set 10 | chapada dos guimaraes
# Processing Record 23 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 24 of Set 10 | boden
# Processing Record 25 of Set 10 | kaspiyskiy
# Processing Record 26 of Set 10 | nioro
# Processing Record 27 of Set 10 | batesville
# Processing Record 28 of Set 10 | pandan
# Processing Record 29 of Set 10 | clearwater
# Processing Record 30 of Set 10 | zyryanka
# Processing Record 31 of Set 10 | pangkalanbuun
# Processing Record 32 of Set 10 | kargasok
# Processing Record 33 of Set 10 | mogadishu
# Processing Record 34 of Set 10 | wanning
# Processing Record 35 of Set 10 | byron bay
# Processing Record 36 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 10 | lavrentiya
# Processing Record 38 of Set 10 | yilan
# Processing Record 39 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 10 | christchurch
# Processing Record 41 of Set 10 | roma
# Processing Record 42 of Set 10 | constitucion
# Processing Record 43 of Set 10 | muros
# Processing Record 44 of Set 10 | talesh
# City not found. Skipping...
# Processing Record 45 of Set 10 | blackwater
# Processing Record 46 of Set 10 | camocim
# Processing Record 47 of Set 10 | phibun mangsahan
# Processing Record 48 of Set 10 | hervey bay
# Processing Record 49 of Set 10 | cienaga
# Processing Record 50 of Set 10 | hobyo
# Processing Record 1 of Set 11 | monrovia
# Processing Record 2 of Set 11 | stephenville
# Processing Record 3 of Set 11 | zharkent
# Processing Record 4 of Set 11 | labuhan
# Processing Record 5 of Set 11 | ishinomaki
# Processing Record 6 of Set 11 | japura
# Processing Record 7 of Set 11 | okhotsk
# Processing Record 8 of Set 11 | istok
# Processing Record 9 of Set 11 | zuenoula
# Processing Record 10 of Set 11 | coaldale
# Processing Record 11 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 11 | zirc
# Processing Record 13 of Set 11 | tadine
# Processing Record 14 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 11 | salinopolis
# Processing Record 16 of Set 11 | kudahuvadhoo
# Processing Record 17 of Set 11 | sadiqabad
# Processing Record 18 of Set 11 | kodinsk
# Processing Record 19 of Set 11 | bathsheba
# Processing Record 20 of Set 11 | coihaique
# Processing Record 21 of Set 11 | tezu
# Processing Record 22 of Set 11 | alyangula
# Processing Record 23 of Set 11 | kabanjahe
# Processing Record 24 of Set 11 | olavarria
# Processing Record 25 of Set 11 | kenai
# Processing Record 26 of Set 11 | latung
# Processing Record 27 of Set 11 | gannan
# Processing Record 28 of Set 11 | kirkwall
# Processing Record 29 of Set 11 | kiunga
# Processing Record 30 of Set 11 | akyab
# Processing Record 31 of Set 11 | pemba
# Processing Record 32 of Set 11 | ust-kuyga
# Processing Record 33 of Set 11 | neiafu
# Processing Record 34 of Set 11 | urumqi
# Processing Record 35 of Set 11 | kula
# Processing Record 36 of Set 11 | kununurra
# Processing Record 37 of Set 11 | matagami
# Processing Record 38 of Set 11 | burica
# City not found. Skipping...
# Processing Record 39 of Set 11 | vao
# Processing Record 40 of Set 11 | timra
# Processing Record 41 of Set 11 | ratnagiri
# Processing Record 42 of Set 11 | alice springs
# Processing Record 43 of Set 11 | benguela
# Processing Record 44 of Set 11 | miri
# Processing Record 45 of Set 11 | dalbandin
# Processing Record 46 of Set 11 | port lincoln
# Processing Record 47 of Set 11 | el fuerte
# Processing Record 48 of Set 11 | hamilton
# Processing Record 49 of Set 11 | makung
# City not found. Skipping...
# Processing Record 50 of Set 11 | anzio
# Processing Record 1 of Set 12 | college place
# Processing Record 2 of Set 12 | madimba
# Processing Record 3 of Set 12 | golspie
# Processing Record 4 of Set 12 | alghero
# Processing Record 5 of Set 12 | paramonga
# Processing Record 6 of Set 12 | cozumel
# Processing Record 7 of Set 12 | erzin
# Processing Record 8 of Set 12 | coulommiers
# Processing Record 9 of Set 12 | ho
# City not found. Skipping...
# Processing Record 10 of Set 12 | georgiyevskoye
# Processing Record 11 of Set 12 | peniche
# Processing Record 12 of Set 12 | harrison
# Processing Record 13 of Set 12 | saryozek
# Processing Record 14 of Set 12 | san juan
# Processing Record 15 of Set 12 | segezha
# Processing Record 16 of Set 12 | carbonia
# Processing Record 17 of Set 12 | yithion
# City not found. Skipping...
# Processing Record 18 of Set 12 | sambava
# Processing Record 19 of Set 12 | handwara
# City not found. Skipping...
# Processing Record 20 of Set 12 | marrakesh
# Processing Record 21 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 12 | kualakapuas
# Processing Record 23 of Set 12 | adrar
# Processing Record 24 of Set 12 | rameswaram
# Processing Record 25 of Set 12 | kedougou
# Processing Record 26 of Set 12 | arlit
# Processing Record 27 of Set 12 | kutum
# Processing Record 28 of Set 12 | ulladulla
# Processing Record 29 of Set 12 | deputatskiy
# Processing Record 30 of Set 12 | olinda
# Processing Record 31 of Set 12 | lanzhou
# Processing Record 32 of Set 12 | mahenge
# Processing Record 33 of Set 12 | northam
# Processing Record 34 of Set 12 | gerash
# Processing Record 35 of Set 12 | brae
# Processing Record 36 of Set 12 | ismailia
# Processing Record 37 of Set 12 | linares
# Processing Record 38 of Set 12 | canico
# Processing Record 39 of Set 12 | tha chang
# Processing Record 40 of Set 12 | virginia beach
# Processing Record 41 of Set 12 | la union
# Processing Record 42 of Set 12 | mattru
# Processing Record 43 of Set 12 | sao geraldo do araguaia
# Processing Record 44 of Set 12 | kanchanaburi
# Processing Record 45 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 47 of Set 12 | iranshahr
# Processing Record 48 of Set 12 | naples
# Processing Record 49 of Set 12 | komsomolskiy
# Processing Record 50 of Set 12 | orlik
# Processing Record 1 of Set 13 | makarska
# Processing Record 2 of Set 13 | liyang
# Processing Record 3 of Set 13 | pokrovsk
# Processing Record 4 of Set 13 | lazaro cardenas
# Processing Record 5 of Set 13 | portree
# Processing Record 6 of Set 13 | joao monlevade
# Processing Record 7 of Set 13 | komarikhinskiy
# Processing Record 8 of Set 13 | daru
# Processing Record 9 of Set 13 | san isidro
# Processing Record 10 of Set 13 | tapes
# Processing Record 11 of Set 13 | bangsund
# Processing Record 12 of Set 13 | gweta
# Processing Record 13 of Set 13 | alta floresta
# Processing Record 14 of Set 13 | truro
# Processing Record 15 of Set 13 | prikubanskiy
# Processing Record 16 of Set 13 | nicolas bravo
# Processing Record 17 of Set 13 | nola
# Processing Record 18 of Set 13 | road town
# Processing Record 19 of Set 13 | khudumelapye
# Processing Record 20 of Set 13 | dolores
# Processing Record 21 of Set 13 | bonthe
# Processing Record 22 of Set 13 | ushibuka
# Processing Record 23 of Set 13 | bjornevatn
# Processing Record 24 of Set 13 | kalianget
# Processing Record 25 of Set 13 | dawson
# Processing Record 26 of Set 13 | amapa
# Processing Record 27 of Set 13 | yuncheng
# Processing Record 28 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 29 of Set 13 | la ronge
# Processing Record 30 of Set 13 | totness
# Processing Record 31 of Set 13 | chinu
# Processing Record 32 of Set 13 | lasa
# Processing Record 33 of Set 13 | mayakonda
# Processing Record 34 of Set 13 | bandarbeyla
# Processing Record 35 of Set 13 | catania
# Processing Record 36 of Set 13 | rio gallegos
# Processing Record 37 of Set 13 | galle
# Processing Record 38 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 39 of Set 13 | dwarka
# Processing Record 40 of Set 13 | novouzensk
# Processing Record 41 of Set 13 | sadove
# Processing Record 42 of Set 13 | orchard homes
# Processing Record 43 of Set 13 | sola
# Processing Record 44 of Set 13 | katete
# Processing Record 45 of Set 13 | springfield
# Processing Record 46 of Set 13 | tuy hoa
# Processing Record 47 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 48 of Set 13 | beloha
# Processing Record 49 of Set 13 | saint-georges
# Processing Record 50 of Set 13 | general roca
# Processing Record 1 of Set 14 | mandalgovi
# Processing Record 2 of Set 14 | tabory
# Processing Record 3 of Set 14 | sao joao da barra
# Processing Record 4 of Set 14 | faranah
# Processing Record 5 of Set 14 | ikungi
# Processing Record 6 of Set 14 | fershampenuaz
# Processing Record 7 of Set 14 | cayenne
# Processing Record 8 of Set 14 | kirovsk
# Processing Record 9 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 11 of Set 14 | turka
# Processing Record 12 of Set 14 | bundaberg
# Processing Record 13 of Set 14 | viedma
# Processing Record 14 of Set 14 | castelo do piaui
# Processing Record 15 of Set 14 | surok
# Processing Record 16 of Set 14 | kulhudhuffushi
# Processing Record 17 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 18 of Set 14 | ambilobe
# Processing Record 19 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 20 of Set 14 | judenburg
# Processing Record 21 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 22 of Set 14 | hengshui
# Processing Record 23 of Set 14 | novosergiyevka
# Processing Record 24 of Set 14 | lakes entrance
# Processing Record 25 of Set 14 | horsham
# Processing Record 26 of Set 14 | aquin
# Processing Record 27 of Set 14 | macapa
# Processing Record 28 of Set 14 | bilozerka
# Processing Record 29 of Set 14 | providencia
# Processing Record 30 of Set 14 | kiruna
# Processing Record 31 of Set 14 | solnechnyy
# Processing Record 32 of Set 14 | zambezi
# Processing Record 33 of Set 14 | ciras
# City not found. Skipping...
# Processing Record 34 of Set 14 | pajarito
# Processing Record 35 of Set 14 | nizhnyaya tavda
# Processing Record 36 of Set 14 | north bend
# Processing Record 37 of Set 14 | kenora
# Processing Record 38 of Set 14 | merauke
# Processing Record 39 of Set 14 | hereford
# Processing Record 40 of Set 14 | ellisras
# Processing Record 41 of Set 14 | bay roberts
# Processing Record 42 of Set 14 | kermanshah
# Processing Record 43 of Set 14 | dukhovnitskoye
# Processing Record 44 of Set 14 | mocuba
# Processing Record 45 of Set 14 | vestmannaeyjar
# Processing Record 46 of Set 14 | stepnoye
# Processing Record 47 of Set 14 | whitehorse
# Processing Record 48 of Set 14 | mareeba
# Processing Record 49 of Set 14 | rabat
# Processing Record 50 of Set 14 | davila
# Processing Record 1 of Set 15 | kloulklubed
# Processing Record 2 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 3 of Set 15 | dingle
# Processing Record 4 of Set 15 | svetlyy
# Processing Record 5 of Set 15 | khani
# Processing Record 6 of Set 15 | aberdeen
# Processing Record 7 of Set 15 | payo
# Processing Record 8 of Set 15 | kiama
# Processing Record 9 of Set 15 | usolye
# Processing Record 10 of Set 15 | platanos
# Processing Record 11 of Set 15 | cap-aux-meules
# Processing Record 12 of Set 15 | hambantota
# Processing Record 13 of Set 15 | kisanga
# Processing Record 14 of Set 15 | kruisfontein
# Processing Record 15 of Set 15 | ruma
# Processing Record 16 of Set 15 | janakpur road
# City not found. Skipping...
# Processing Record 17 of Set 15 | sistranda
# Processing Record 18 of Set 15 | kelvington
# Processing Record 19 of Set 15 | mahanoro
# Processing Record 20 of Set 15 | bossier city
# Processing Record 21 of Set 15 | bowen
# Processing Record 22 of Set 15 | waingapu
# Processing Record 23 of Set 15 | miraflores
# Processing Record 24 of Set 15 | partenit
# Processing Record 25 of Set 15 | feijo
# Processing Record 26 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 27 of Set 15 | malindi
# Processing Record 28 of Set 15 | auki
# Processing Record 29 of Set 15 | durusu
# Processing Record 30 of Set 15 | mount gambier
# Processing Record 31 of Set 15 | san carlos de bariloche
# Processing Record 32 of Set 15 | shenjiamen
# Processing Record 33 of Set 15 | sipka
# City not found. Skipping...
# Processing Record 34 of Set 15 | kirakira
# Processing Record 35 of Set 15 | belaya gora
# Processing Record 36 of Set 15 | gongzhuling
# Processing Record 37 of Set 15 | mogochin
# City not found. Skipping...
# Processing Record 38 of Set 15 | maxixe
# Processing Record 39 of Set 15 | gaogou
# Processing Record 40 of Set 15 | rjukan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert to DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Ushuaia -54.8000  -68.3000     40.66        81         100
# 1           Magadan  59.5667  150.8000     -5.19        67          40
# 2           Kavieng  -2.5744  150.7967     81.09        78          97
# 3             Kapaa  22.0752 -159.3190     76.12        69          59
# 4    Port Elizabeth -33.9180   25.5701     70.09        78           0
# ..              ...      ...       ...       ...       ...         ...
# 668     Belaya Gora  68.5333  146.4167    -19.68        95          92
# 669     Gongzhuling  43.5008  124.8198      8.44        78         100
# 670          Maxixe -23.8597   35.3472     75.67        87           1
# 671          Gaogou  34.0175  119.1886     37.38        77          12
# 672          Rjukan  59.8789    8.5941     39.65        98         100
#
#      Wind Speed Country       Description                 Date
# 0         39.12      AR     moderate rain  2022-02-13 20:53:16
# 1          9.64      RU  scattered clouds  2022-02-13 20:53:16
# 2          6.31      PG   overcast clouds  2022-02-13 20:53:17
# 3          1.99      US     broken clouds  2022-02-13 20:53:17
# 4         11.50      ZA         clear sky  2022-02-13 20:53:17
# ..          ...     ...               ...                  ...
# 668        5.68      RU   overcast clouds  2022-02-13 20:57:35
# 669       12.01      CN   overcast clouds  2022-02-13 20:57:35
# 670        7.40      MZ         clear sky  2022-02-13 20:55:07
# 671        4.14      CN        few clouds  2022-02-13 20:57:36
# 672        2.19      NO        light rain  2022-02-13 20:54:56
#
# [673 rows x 10 columns]

# %%
new_column_order=["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0         Ushuaia      AR  2022-02-13 20:53:16 -54.8000  -68.3000     40.66
# 1         Magadan      RU  2022-02-13 20:53:16  59.5667  150.8000     -5.19
# 2         Kavieng      PG  2022-02-13 20:53:17  -2.5744  150.7967     81.09
# 3           Kapaa      US  2022-02-13 20:53:17  22.0752 -159.3190     76.12
# 4  Port Elizabeth      ZA  2022-02-13 20:53:17 -33.9180   25.5701     70.09
# 5           Seoul      KR  2022-02-13 20:51:30  37.5683  126.9778     27.79
# 6    Krasnoselkup      RU  2022-02-13 20:53:18  65.7000   82.4667     -0.96
# 7         Rikitea      PF  2022-02-13 20:53:18 -23.1203 -134.9692     78.46
# 8          Hobart      AU  2022-02-13 20:52:19 -42.8794  147.3294     62.02
# 9    Puerto Ayora      EC  2022-02-13 20:53:19  -0.7393  -90.3518     80.56
#
#    Humidity  Cloudiness  Wind Speed       Description
# 0        81         100       39.12     moderate rain
# 1        67          40        9.64  scattered clouds
# 2        78          97        6.31   overcast clouds
# 3        69          59        1.99     broken clouds
# 4        78           0       11.50         clear sky
# 5        87           0        3.44         clear sky
# 6        92          72       13.27     broken clouds
# 7        72          83       11.50        light rain
# 8        81          75       11.50     broken clouds
# 9        88          91        5.99   overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
